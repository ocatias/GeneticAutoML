# %%
import pandas as pd

import importlib
import timeit

import GenAlgo_1 as GA

from sklearn.model_selection import train_test_split

importlib.reload(GA)
# Out:
# <module 'GenAlgo_1' from '/home/atse/Documents/Studium/ML/ML-Ex3/GenAlgo_1.py'>

# %%
importlib.reload(GA)
test_duration = 15*60
do_cv = True
nr_cv = 3

# %%
filepath = "car.data"
data = pd.read_csv(filepath, header =None) 


from sklearn.preprocessing import LabelEncoder 


#Replace those by labels
for col in data:
    labelencoder = LabelEncoder()
    data[col] = labelencoder.fit_transform(data[col])

print(data.dtypes)

y = data[6]
X = data.drop(axis=1, labels=6)

print(X)
print(y)







X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 0)
# Out:
# 0    int64
# 1    int64
# 2    int64
# 3    int64
# 4    int64
# 5    int64
# 6    int64
# dtype: object
#       0  1  2  3  4  5
# 0     3  3  0  0  2  1
# 1     3  3  0  0  2  2
# 2     3  3  0  0  2  0
# 3     3  3  0  0  1  1
# 4     3  3  0  0  1  2
# ...  .. .. .. .. .. ..
# 1723  1  1  3  2  1  2
# 1724  1  1  3  2  1  0
# 1725  1  1  3  2  0  1
# 1726  1  1  3  2  0  2
# 1727  1  1  3  2  0  0
#
# [1728 rows x 6 columns]
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 1723    1
# 1724    3
# 1725    2
# 1726    1
# 1727    3
# Name: 6, Length: 1728, dtype: int64

# %%
print(X.head(), y)
# Out:
#    0  1  2  3  4  5
# 0  3  3  0  0  2  1
# 1  3  3  0  0  2  2
# 2  3  3  0  0  2  0
# 3  3  3  0  0  1  1
# 4  3  3  0  0  1  2 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 1723    1
# 1724    3
# 1725    2
# 1726    1
# 1727    3
# Name: 6, Length: 1728, dtype: int64

# %%
i = 10

print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
print("Number of individuals is " + str(i))
start = timeit.default_timer()
GenAutoML = GA.GenAutoML(verbose=11, crossvalidate=do_cv, cv= nr_cv, n_jobs=-1,nr_individuals=i,nr_iterations=100000, timelimit=test_duration, max_nu=0.001)
GenAutoML.fit(X_train,y_train)
stop = timeit.default_timer()

GenAutoML.predict(X_test, y_test)
# Out:
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# Number of individuals is 10
# Initialising class
# Individuals: 10
# Iterations: 100000
# Threads: all
# Elitism: True
# Crossvalidate:  3 fold
# Genetic Feature Selection:  No
# Equal Distribution of individuals to algos:  No
#
#
# Generation  0
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done   2 out of  10 | elapsed:    1.8s remaining:    7.3s
# [Parallel(n_jobs=-1)]: Done   3 out of  10 | elapsed:    1.9s remaining:    4.5s
# [Parallel(n_jobs=-1)]: Done   4 out of  10 | elapsed:    2.0s remaining:    3.0s
# [Parallel(n_jobs=-1)]: Done   5 out of  10 | elapsed:    2.2s remaining:    2.2s
# [Parallel(n_jobs=-1)]: Done   6 out of  10 | elapsed:    2.3s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done   7 out of  10 | elapsed:    5.5s remaining:    2.3s
# ...

# %%
i = 20

print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
print("Number of individuals is " + str(i))
start = timeit.default_timer()
GenAutoML = GA.GenAutoML(crossvalidate=do_cv, cv= nr_cv, n_jobs=-1,nr_individuals=i,nr_iterations=100000, timelimit=test_duration, max_nu = 0.001)
GenAutoML.fit(X_train,y_train)
stop = timeit.default_timer()

GenAutoML.predict(X_test, y_test)
# Out:
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# Number of individuals is 20
# Initialising class
# Individuals: 20
# Iterations: 100000
# Threads: all
# Elitism: True
# Crossvalidate:  3 fold
# Genetic Feature Selection:  No
# Equal Distribution of individuals to algos:  No
#
#
# Generation  0
# Best Score:  0.9427307319639889
# Average:  0.3663732458069062
# Worst Score:  0.09436311167654451
# Best individual score:  0.9427307319639889
# {'NuSVC': 4, 'RF': 4, 'Ridge': 4, 'XGBoost': 4, 'Radius': 4}
#  {'NuSVC': 0.9427307319639889, 'RF': 0.8223797333400509, 'Ridge': 0.25739932809388444, 'XGBoost': 0.7953657051836438, 'Radius': 0.20601589103291715}
#
#
# Generation  1
# Best Score:  0.9427307319639889
# Average:  0.5222798594345075
# Worst Score:  0.20601589103291715
# Best individual score:  0.9427307319639889
# {'NuSVC': 2, 'RF': 8, 'Ridge': 2, 'XGBoost': 5, 'Radius': 3}
# ...

# %%
i = 50

print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
print("Number of individuals is " + str(i))
start = timeit.default_timer()
GenAutoML = GA.GenAutoML(crossvalidate=do_cv, cv= nr_cv, n_jobs=-1,nr_individuals=i,nr_iterations=100000, timelimit=test_duration, max_nu = 0.001)
GenAutoML.fit(X_train,y_train)
stop = timeit.default_timer()

GenAutoML.predict(X_test, y_test)
# Out:
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# Number of individuals is 50
# Initialising class
# Individuals: 50
# Iterations: 100000
# Threads: all
# Elitism: True
# Crossvalidate:  3 fold
# Genetic Feature Selection:  No
# Equal Distribution of individuals to algos:  No
#
#
# Generation  0
# Best Score:  0.9532409166387299
# Average:  0.31977869694736766
# Worst Score:  0.08119298265116313
# Best individual score:  0.9532409166387299
# {'NuSVC': 10, 'RF': 10, 'Ridge': 10, 'XGBoost': 10, 'Radius': 10}
#  {'NuSVC': 0.9532409166387299, 'RF': 0.8223797333400509, 'Ridge': 0.25739932809388444, 'XGBoost': 0.7936808892362623, 'Radius': 0.5616537424511806}
#
#
# Generation  1
# Best Score:  0.9532409166387299
# Average:  0.4310467020009067
# Worst Score:  0.0909756259886648
# Best individual score:  0.9532409166387299
# {'NuSVC': 10, 'RF': 11, 'Ridge': 8, 'XGBoost': 12, 'Radius': 9}
# ...

# %%
i = 100

print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
print("Number of individuals is " + str(i))
start = timeit.default_timer()
GenAutoML = GA.GenAutoML(crossvalidate=do_cv, cv= nr_cv, n_jobs=-1,nr_individuals=i,nr_iterations=100000, timelimit=test_duration, max_nu = 0.001)
GenAutoML.fit(X_train,y_train)
stop = timeit.default_timer()

GenAutoML.predict(X_test, y_test)
# Out:
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# Number of individuals is 100
# Initialising class
# Individuals: 100
# Iterations: 100000
# Threads: all
# Elitism: True
# Crossvalidate:  3 fold
# Genetic Feature Selection:  No
# Equal Distribution of individuals to algos:  No
#
#
# Generation  0
# Best Score:  0.9532409166387299
# Average:  0.3022089934429426
# Worst Score:  0.09436311167654451
# Best individual score:  0.9532409166387299
# {'NuSVC': 20, 'RF': 20, 'Ridge': 20, 'XGBoost': 20, 'Radius': 20}
#  {'NuSVC': 0.9532409166387299, 'RF': 0.6223642258485464, 'Ridge': 0.25739932809388444, 'XGBoost': 0.7366321717929882, 'Radius': 0.8630179344465059}
#
#
# Generation  1
# Best Score:  0.9532409166387299
# Average:  0.3549720857916954
# Worst Score:  0.08678659796444149
# Best individual score:  0.9532409166387299
# {'NuSVC': 15, 'RF': 21, 'Ridge': 23, 'XGBoost': 25, 'Radius': 16}
# ...

# %%
i = 250

print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
print("Number of individuals is " + str(i))
start = timeit.default_timer()
GenAutoML = GA.GenAutoML(crossvalidate=do_cv, cv= nr_cv, n_jobs=-1,nr_individuals=i,nr_iterations=100000, timelimit=test_duration, max_nu = 0.001)
GenAutoML.fit(X_train,y_train)
stop = timeit.default_timer()

GenAutoML.predict(X_test, y_test)
# Out:
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# Number of individuals is 250
# Initialising class
# Individuals: 250
# Iterations: 100000
# Threads: all
# Elitism: True
# Crossvalidate:  3 fold
# Genetic Feature Selection:  No
# Equal Distribution of individuals to algos:  No
#
#
# Generation  0
# Best Score:  0.9595741958187374
# Average:  0.2975222852824421
# Worst Score:  0.07562047916120629
# Best individual score:  0.9595741958187374
# {'NuSVC': 50, 'RF': 50, 'Ridge': 50, 'XGBoost': 50, 'Radius': 50}
#  {'NuSVC': 0.9595741958187374, 'RF': 0.8849277643744047, 'Ridge': 0.25739932809388444, 'XGBoost': 0.916311822950827, 'Radius': 0.6248168153996575}
#
#
# Generation  1
# Best Score:  0.9595741958187374
# Average:  0.4059231403969443
# Worst Score:  0.07244970051889126
# Best individual score:  0.9595741958187374
# {'NuSVC': 37, 'RF': 56, 'Ridge': 52, 'XGBoost': 66, 'Radius': 39}
# ...

# %%
i = True    
    
print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
print("Equal distribution " + str(i))
start = timeit.default_timer()
GenAutoML = GA.GenAutoML(crossvalidate=do_cv, cv= nr_cv, n_jobs=-1,nr_iterations=100000, equal_distribution=i, timelimit=test_duration, max_nu = 0.001)
GenAutoML.fit(X_train,y_train)
stop = timeit.default_timer()

GenAutoML.predict(X_test, y_test)
# Out:
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# Equal distribution True
# Initialising class
# Individuals: 100
# Iterations: 100000
# Threads: all
# Elitism: True
# Crossvalidate:  3 fold
# Genetic Feature Selection:  No
# Equal Distribution of individuals to algos:  Yes
#
#
# Generation  0
# Best Score:  0.9595741958187374
# Average:  0.31577369410339207
# Worst Score:  0.09659250374655681
# Best individual score:  0.9595741958187374
# {'NuSVC': 20, 'RF': 20, 'Ridge': 20, 'XGBoost': 20, 'Radius': 20}
#  {'NuSVC': 0.9595741958187374, 'RF': 0.8614271763911434, 'Ridge': 0.25739932809388444, 'XGBoost': 0.8782809343179008, 'Radius': 0.5616537424511806}
#
#
# Generation  1
# Best Score:  0.9595741958187374
# Average:  0.4456613377786303
# Worst Score:  0.0995622306432638
# Best individual score:  0.9595741958187374
# {'NuSVC': 20, 'RF': 20, 'Ridge': 20, 'XGBoost': 20, 'Radius': 20}
# ...

# %%
i = False 
    
print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
print("Equal distribution " + str(i))
start = timeit.default_timer()
GenAutoML = GA.GenAutoML(crossvalidate=do_cv, cv= nr_cv, n_jobs=-1,nr_iterations=100000, equal_distribution=i, timelimit=test_duration, max_nu = 0.001)
GenAutoML.fit(X_train,y_train)
stop = timeit.default_timer()

GenAutoML.predict(X_test, y_test)
# Out:
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# Equal distribution False
# Initialising class
# Individuals: 100
# Iterations: 100000
# Threads: all
# Elitism: True
# Crossvalidate:  3 fold
# Genetic Feature Selection:  No
# Equal Distribution of individuals to algos:  No
#
#
# Generation  0
# Best Score:  0.9532409166387299
# Average:  0.3059833684335386
# Worst Score:  0.09436311167654451
# Best individual score:  0.9532409166387299
# {'NuSVC': 20, 'RF': 20, 'Ridge': 20, 'XGBoost': 20, 'Radius': 20}
#  {'NuSVC': 0.9532409166387299, 'RF': 0.8239746297846589, 'Ridge': 0.25739932809388444, 'XGBoost': 0.823626551255326, 'Radius': 0.8630179344465059}
#
#
# Generation  1
# Best Score:  0.9599454659790194
# Average:  0.44646933369946074
# Worst Score:  0.1042462870293059
# Best individual score:  0.9599454659790194
# {'NuSVC': 13, 'RF': 31, 'Ridge': 15, 'XGBoost': 24, 'Radius': 17}
# ...

# %%
i = True

print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
print("Elitism  " + str(i))
start = timeit.default_timer()
GenAutoML = GA.GenAutoML(crossvalidate=do_cv, cv= nr_cv, n_jobs=-1,nr_iterations=100000, elitism=i, timelimit=test_duration, max_nu = 0.001)
GenAutoML.fit(X_train,y_train)
stop = timeit.default_timer()

GenAutoML.predict(X_test, y_test)
# Out:
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# Elitism  True
# Initialising class
# Individuals: 100
# Iterations: 100000
# Threads: all
# Elitism: True
# Crossvalidate:  3 fold
# Genetic Feature Selection:  No
# Equal Distribution of individuals to algos:  No
#
#
# Generation  0
# Best Score:  0.950153849673427
# Average:  0.280081657115398
# Worst Score:  0.08901683650806601
# Best individual score:  0.950153849673427
# {'NuSVC': 20, 'RF': 20, 'Ridge': 20, 'XGBoost': 20, 'Radius': 20}
#  {'NuSVC': 0.950153849673427, 'RF': 0.8208182636406294, 'Ridge': 0.25739932809388444, 'XGBoost': 0.8598613595833577, 'Radius': 0.8630179344465059}
#
#
# Generation  1
# Best Score:  0.9585528420386508
# Average:  0.42205662403606875
# Worst Score:  0.09436311167654451
# Best individual score:  0.9585528420386508
# {'NuSVC': 14, 'RF': 23, 'Ridge': 15, 'XGBoost': 28, 'Radius': 20}
# ...

# %%
i = False

print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
print("Elitism  " + str(i))
start = timeit.default_timer()
GenAutoML = GA.GenAutoML(crossvalidate=do_cv, cv= nr_cv, n_jobs=-1,nr_iterations=100000, elitism=i, timelimit=test_duration, max_nu = 0.001)
GenAutoML.fit(X_train,y_train)
stop = timeit.default_timer()

GenAutoML.predict(X_test, y_test)
# Out:
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# Elitism  False
# Initialising class
# Individuals: 100
# Iterations: 100000
# Threads: all
# Elitism: False
# Crossvalidate:  3 fold
# Genetic Feature Selection:  No
# Equal Distribution of individuals to algos:  No
#
#
# Generation  0
# Best Score:  0.9518492518483225
# Average:  0.3091436064214516
# Worst Score:  0.09702583167586426
# Best individual score:  0.9518492518483225
# {'NuSVC': 20, 'RF': 20, 'Ridge': 20, 'XGBoost': 20, 'Radius': 20}
#  {'NuSVC': 0.9518492518483225, 'RF': 0.8492528697969626, 'Ridge': 0.25739932809388444, 'XGBoost': 0.9169704677855374, 'Radius': 0.5616537424511806}
#
#
# Generation  1
# Best Score:  0.9584826489194428
# Average:  0.44723687996511585
# Worst Score:  0.0910655369036793
# Best individual score:  0.9584826489194428
# {'NuSVC': 19, 'RF': 29, 'Ridge': 15, 'XGBoost': 23, 'Radius': 14}
# ...

# %%
i = 0.001


print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
print("Chance that algo param will mutate is " + str(i))
start = timeit.default_timer()
GenAutoML = GA.GenAutoML(crossvalidate=do_cv, cv= nr_cv, n_jobs=-1,nr_iterations=100000, mutation_chance_algo=i, timelimit=test_duration, max_nu = 0.001)
GenAutoML.fit(X_train,y_train)
stop = timeit.default_timer()

GenAutoML.predict(X_test, y_test)
# Out:
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# Chance that algo param will mutate is 0.001
# Initialising class
# Individuals: 100
# Iterations: 100000
# Threads: all
# Elitism: True
# Crossvalidate:  3 fold
# Genetic Feature Selection:  No
# Equal Distribution of individuals to algos:  No
#
#
# Generation  0
# Best Score:  0.9595106294747233
# Average:  0.30504192352239395
# Worst Score:  0.09505567608531611
# Best individual score:  0.9595106294747233
# {'NuSVC': 20, 'RF': 20, 'Ridge': 20, 'XGBoost': 20, 'Radius': 20}
#  {'NuSVC': 0.9595106294747233, 'RF': 0.6136101224322588, 'Ridge': 0.25739932809388444, 'XGBoost': 0.7869906992856537, 'Radius': 0.20601589103291715}
#
#
# Generation  1
# Best Score:  0.9595106294747233
# Average:  0.5091334452940739
# Worst Score:  0.10557389837140485
# Best individual score:  0.9595106294747233
# {'NuSVC': 31, 'RF': 23, 'Ridge': 13, 'XGBoost': 22, 'Radius': 11}
# ...

# %%
i = 0.005


print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
print("Chance that algo param will mutate is " + str(i))
start = timeit.default_timer()
GenAutoML = GA.GenAutoML(crossvalidate=do_cv, cv= nr_cv, n_jobs=-1,nr_iterations=100000, mutation_chance_algo=i, timelimit=test_duration, max_nu = 0.001)
GenAutoML.fit(X_train,y_train)
stop = timeit.default_timer()

GenAutoML.predict(X_test, y_test)
# Out:
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# Chance that algo param will mutate is 0.005
# Initialising class
# Individuals: 100
# Iterations: 100000
# Threads: all
# Elitism: True
# Crossvalidate:  3 fold
# Genetic Feature Selection:  No
# Equal Distribution of individuals to algos:  No
#
#
# Generation  0
# Best Score:  0.9518492518483225
# Average:  0.30646749571018456
# Worst Score:  0.09004739336492891
# Best individual score:  0.9518492518483225
# {'NuSVC': 20, 'RF': 20, 'Ridge': 20, 'XGBoost': 20, 'Radius': 20}
#  {'NuSVC': 0.9518492518483225, 'RF': 0.8760326824747402, 'Ridge': 0.25739932809388444, 'XGBoost': 0.5978532919532058, 'Radius': 0.8630179344465059}
#
#
# Generation  1
# Best Score:  0.9518492518483225
# Average:  0.47487840839328205
# Worst Score:  0.09004739336492891
# Best individual score:  0.9518492518483225
# {'NuSVC': 20, 'RF': 20, 'Ridge': 20, 'XGBoost': 16, 'Radius': 24}
# ...

# %%
i = 0.01


print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
print("Chance that algo param will mutate is " + str(i))
start = timeit.default_timer()
GenAutoML = GA.GenAutoML(crossvalidate=do_cv, cv= nr_cv, n_jobs=-1,nr_iterations=100000, mutation_chance_algo=i, timelimit=test_duration, max_nu = 0.001)
GenAutoML.fit(X_train,y_train)
stop = timeit.default_timer()

GenAutoML.predict(X_test, y_test)
# Out:
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# Chance that algo param will mutate is 0.01
# Initialising class
# Individuals: 100
# Iterations: 100000
# Threads: all
# Elitism: True
# Crossvalidate:  3 fold
# Genetic Feature Selection:  No
# Equal Distribution of individuals to algos:  No
#
#
# Generation  0
# Best Score:  0.9518492518483225
# Average:  0.2824094850636608
# Worst Score:  0.0938461750771323
# Best individual score:  0.9518492518483225
# {'NuSVC': 20, 'RF': 20, 'Ridge': 20, 'XGBoost': 20, 'Radius': 20}
#  {'NuSVC': 0.9518492518483225, 'RF': 0.8239314017556332, 'Ridge': 0.25739932809388444, 'XGBoost': 0.9223239785072158, 'Radius': 0.5531391614620651}
#
#
# Generation  1
# Best Score:  0.9532409166387299
# Average:  0.43393399237470986
# Worst Score:  0.11156156486534062
# Best individual score:  0.9532409166387299
# {'NuSVC': 17, 'RF': 19, 'Ridge': 14, 'XGBoost': 35, 'Radius': 15}
# ...

# %%
i = 0.025


print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
print("Chance that algo param will mutate is " + str(i))
start = timeit.default_timer()
GenAutoML = GA.GenAutoML(crossvalidate=do_cv, cv= nr_cv, n_jobs=-1,nr_iterations=100000, mutation_chance_algo=i, timelimit=test_duration, max_nu = 0.001)
GenAutoML.fit(X_train,y_train)
stop = timeit.default_timer()

GenAutoML.predict(X_test, y_test)
# Out:
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# Chance that algo param will mutate is 0.025
# Initialising class
# Individuals: 100
# Iterations: 100000
# Threads: all
# Elitism: True
# Crossvalidate:  3 fold
# Genetic Feature Selection:  No
# Equal Distribution of individuals to algos:  No
#
#
# Generation  0
# Best Score:  0.9609819896369605
# Average:  0.3266197313404411
# Worst Score:  0.0935114149123437
# Best individual score:  0.9609819896369605
# {'NuSVC': 20, 'RF': 20, 'Ridge': 20, 'XGBoost': 20, 'Radius': 20}
#  {'NuSVC': 0.9609819896369605, 'RF': 0.6890748269996857, 'Ridge': 0.25739932809388444, 'XGBoost': 0.799545447708772, 'Radius': 0.6248168153996575}
#
#
# Generation  1
# Best Score:  0.9609819896369605
# Average:  0.4761807125838665
# Worst Score:  0.09436311167654451
# Best individual score:  0.9609819896369605
# {'NuSVC': 25, 'RF': 21, 'Ridge': 18, 'XGBoost': 25, 'Radius': 11}
# ...

# %%
i = 0.05


print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
print("Chance that algo param will mutate is " + str(i))
start = timeit.default_timer()
GenAutoML = GA.GenAutoML(crossvalidate=do_cv, cv= nr_cv, n_jobs=-1,nr_iterations=100000, mutation_chance_algo=i, timelimit=test_duration, max_nu = 0.001)
GenAutoML.fit(X_train,y_train)
stop = timeit.default_timer()

GenAutoML.predict(X_test, y_test)
# Out:
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# Chance that algo param will mutate is 0.05
# Initialising class
# Individuals: 100
# Iterations: 100000
# Threads: all
# Elitism: True
# Crossvalidate:  3 fold
# Genetic Feature Selection:  No
# Equal Distribution of individuals to algos:  No
#
#
# Generation  0
# Best Score:  0.9518492518483225
# Average:  0.2638093008264128
# Worst Score:  0.08336466355668291
# Best individual score:  0.9518492518483225
# {'NuSVC': 20, 'RF': 20, 'Ridge': 20, 'XGBoost': 20, 'Radius': 20}
#  {'NuSVC': 0.9518492518483225, 'RF': 0.6196514334144997, 'Ridge': 0.25739932809388444, 'XGBoost': 0.5482428115213818, 'Radius': 0.8630179344465059}
#
#
# Generation  1
# Best Score:  0.9532409166387299
# Average:  0.3191899714330586
# Worst Score:  0.08336466355668291
# Best individual score:  0.9532409166387299
# {'NuSVC': 18, 'RF': 20, 'Ridge': 29, 'XGBoost': 23, 'Radius': 10}
# ...

# %%
i = True

print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
print("Genetic feature selection " + str(i))
start = timeit.default_timer()
GenAutoML = GA.GenAutoML(crossvalidate=do_cv, cv= nr_cv, n_jobs=-1,nr_iterations=100000, genetic_feature_selection=i, timelimit=test_duration, max_nu = 0.001)
GenAutoML.fit(X_train,y_train)
stop = timeit.default_timer()

GenAutoML.predict(X_test, y_test)
# Out:
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# Genetic feature selection True
# Initialising class
# Individuals: 100
# Iterations: 100000
# Threads: all
# Elitism: True
# Crossvalidate:  3 fold
# Genetic Feature Selection:  Yes
# Equal Distribution of individuals to algos:  No
#
# WARNING GENETIC FEATURE SELECTION IS TURNED ON! This has a very high chance to drastically reduce the score on the test dataset.
#
# WARNING GENETIC FEATURE SELECTION IS TURNED ON! This has a very high chance to drastically reduce the score on the test dataset.
#
# WARNING GENETIC FEATURE SELECTION IS TURNED ON! This has a very high chance to drastically reduce the score on the test dataset.
#
# WARNING GENETIC FEATURE SELECTION IS TURNED ON! This has a very high chance to drastically reduce the score on the test dataset.
#
# WARNING GENETIC FEATURE SELECTION IS TURNED ON! This has a very high chance to drastically reduce the score on the test dataset.
#
#
#
# Generation  0
# ...

# %%
i = False

print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
print("Genetic feature selection " + str(i))
start = timeit.default_timer()
GenAutoML = GA.GenAutoML(crossvalidate=do_cv, cv= nr_cv, n_jobs=-1,nr_iterations=100000, genetic_feature_selection=i, timelimit=test_duration, max_nu = 0.001)
GenAutoML.fit(X_train,y_train)
stop = timeit.default_timer()

GenAutoML.predict(X_test, y_test)
# Out:
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# Genetic feature selection False
# Initialising class
# Individuals: 100
# Iterations: 100000
# Threads: all
# Elitism: True
# Crossvalidate:  3 fold
# Genetic Feature Selection:  No
# Equal Distribution of individuals to algos:  No
#
#
# Generation  0
# Best Score:  0.9532409166387299
# Average:  0.322484159387142
# Worst Score:  0.0935114149123437
# Best individual score:  0.9532409166387299
# {'NuSVC': 20, 'RF': 20, 'Ridge': 20, 'XGBoost': 20, 'Radius': 20}
#  {'NuSVC': 0.9532409166387299, 'RF': 0.8400964376956931, 'Ridge': 0.25739932809388444, 'XGBoost': 0.8755553934295832, 'Radius': 0.2585955113752818}
#
#
# Generation  1
# Best Score:  0.9581031361245786
# Average:  0.44054390027603985
# Worst Score:  0.09436311167654451
# Best individual score:  0.9581031361245786
# {'NuSVC': 21, 'RF': 26, 'Ridge': 13, 'XGBoost': 24, 'Radius': 16}
# ...
