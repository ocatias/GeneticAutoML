# %%
import pandas as pd

import importlib
import timeit

import GenAlgo_1 as GA

from sklearn.model_selection import train_test_split

importlib.reload(GA)

from sklearn.preprocessing import LabelEncoder

def labelEncoding(data):
    data_labelenc = data.copy()

    #Find columns with categorical values
    s = (data_labelenc.dtypes == 'object')
    object_cols = list(s[s].index)

    #Replace those by labels
    for col in object_cols:
        labels_df = pd.DataFrame(data_labelenc, columns=[col])
        labelencoder = LabelEncoder()
        data_labelenc[col] = labelencoder.fit_transform(labels_df[col])

    return data_labelenc

# %%
filepath = "tic-tac-toe.csv"
data = pd.read_csv(filepath, header=None) 
y = data[9]
X = data.drop(axis=1, labels=9)
X = labelEncoding(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
importlib.reload(GA)

start = timeit.default_timer()
GenAutoML = GA.GenAutoML(n_jobs=1,nr_individuals=200,nr_iterations=2, timelimit=12000, 
                         equal_distribution = False,  simple_data = True, verbose = 11)
GenAutoML.fit(X_train,y_train)
stop = timeit.default_timer()

print('\nRuntime: ', stop - start, 's')
# Out:
# Initialising class
# Individuals: 200
# Iterations: 2
# Threads: 1
# Elitism: True
# Crossvalidate:  No
# Genetic Feature Selection:  No
# Equal Distribution of individuals to algos:  No
#
#
# Generation  0
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.9s remaining:    0.0s
# ...

# %%
importlib.reload(GA)

start = timeit.default_timer()
GenAutoML = GA.GenAutoML(n_jobs=2,nr_individuals=200,nr_iterations=2, timelimit=12000, 
                         equal_distribution = False,  simple_data = True, verbose = 11)
GenAutoML.fit(X_train,y_train)
stop = timeit.default_timer()

print('\nRuntime: ', stop - start, 's')
# Out:
# Initialising class
# Individuals: 200
# Iterations: 2
# Threads: 2
# Elitism: True
# Crossvalidate:  No
# Genetic Feature Selection:  No
# Equal Distribution of individuals to algos:  No
#
#
# Generation  0
# [Parallel(n_jobs=2)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done   1 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=2)]: Done   2 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=2)]: Done   3 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=2)]: Done   4 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=2)]: Done   5 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=2)]: Done   6 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=2)]: Done   7 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=2)]: Done   8 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=2)]: Done   9 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=2)]: Done  10 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=2)]: Done  11 tasks      | elapsed:    1.9s
# ...

# %%
importlib.reload(GA)

start = timeit.default_timer()
GenAutoML = GA.GenAutoML(n_jobs=-1,nr_individuals=200,nr_iterations=2, timelimit=12000, 
                         equal_distribution = False,  simple_data = True, verbose = 11)
GenAutoML.fit(X_train,y_train)
stop = timeit.default_timer()

print('\nRuntime: ', stop - start, 's')
# Out:
# Initialising class
# Individuals: 200
# Iterations: 2
# Threads: all
# Elitism: True
# Crossvalidate:  No
# Genetic Feature Selection:  No
# Equal Distribution of individuals to algos:  No
#
#
# Generation  0
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:    3.3s
# ...

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

objects = ('1 Thread', '2 Threads', '12 Threads')
y_pos = np.arange(len(objects))
performance = [279,194,63]

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Time [s]')
plt.title('Effect of Parallelisation')
plt.savefig('parallelisation.pdf')

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

objects = ('1 Thread', '2 Threads', '12 Threads')
y_pos = np.arange(len(objects))
performance = [313,164,55]

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Time [s]')
plt.title('Effect of Parallelisation')
plt.savefig('parallelisation.pdf')
